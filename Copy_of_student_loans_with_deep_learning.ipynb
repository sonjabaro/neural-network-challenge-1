# %% [markdown]
# <a href="https://colab.research.google.com/github/sonjabaro/neural-network-challenge-1/blob/main/Copy_of_student_loans_with_deep_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Student Loan Risk with Deep Learning

# %%
# Imports
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from pathlib import Path

# %% [markdown]
# ---
#
# ## Prepare the data to be used on a neural network model

# %% [markdown]
# ### Step 1: Read the `student-loans.csv` file into a Pandas DataFrame. Review the DataFrame, looking for columns that could eventually define your features and target variables.

# %%
# Read the csv into a Pandas DataFrame
file_path = "https://static.bc-edx.com/ai/ail-v-1-0/m18/lms/datasets/student-loans.csv"
loans_df = pd.read_csv(file_path)

# Review the DataFrame
loans_df.head()
# Out:
#    payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 0              7.4                0.70               0.00          1.9
# 1              7.8                0.88               0.00          2.6
# 2              7.8                0.76               0.04          2.3
# 3             11.2                0.28               0.56          1.9
# 4              7.4                0.70               0.00          1.9
#
#    alumni_success  study_major_code  time_to_completion  \
# 0           0.076              11.0                34.0
# 1           0.098              25.0                67.0
# 2           0.092              15.0                54.0
# 3           0.075              17.0                60.0
# 4           0.076              11.0                34.0
#
#    finance_workshop_score  cohort_ranking  total_loan_score  \
# 0                  0.9978            3.51              0.56
# 1                  0.9968            3.20              0.68
# ...

# %%
# Review the data types associated with the columns
loans_df.dtypes
# Out:
# payment_history           float64
# location_parameter        float64
# stem_degree_score         float64
# gpa_ranking               float64
# alumni_success            float64
# study_major_code          float64
# time_to_completion        float64
# finance_workshop_score    float64
# cohort_ranking            float64
# total_loan_score          float64
# financial_aid_score       float64
# credit_ranking              int64
# dtype: object

# %%
# Check the credit_ranking value counts
loans_df["credit_ranking"].value_counts()
# Out:
# 1    855
# 0    744
# Name: credit_ranking, dtype: int64

# %%
loans_df.shape
# Out:
# (1599, 12)

# %%
import numpy as np

# %%
loans_df.describe()
# Out:
#        payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# count      1599.000000         1599.000000        1599.000000  1599.000000
# mean          8.319637            0.527821           0.270976     2.538806
# std           1.741096            0.179060           0.194801     1.409928
# min           4.600000            0.120000           0.000000     0.900000
# 25%           7.100000            0.390000           0.090000     1.900000
# 50%           7.900000            0.520000           0.260000     2.200000
# 75%           9.200000            0.640000           0.420000     2.600000
# max          15.900000            1.580000           1.000000    15.500000
#
#        alumni_success  study_major_code  time_to_completion  \
# count     1599.000000       1599.000000         1599.000000
# mean         0.087467         15.874922           46.467792
# std          0.047065         10.460157           32.895324
# ...

# %%
#scale the data
#scaler = StandardScaler()
#df_scaled = pd.DataFrame(scaler.fit_transform(loans_df),columns = loans_df.columns)
#df_scaled.head()

# %% [markdown]
# ### Step 2: Using the preprocessed data, create the features (`X`) and target (`y`) datasets. The target dataset should be defined by the preprocessed DataFrame column “credit_ranking”. The remaining columns should define the features dataset.

# %%
# Define the target set y using the credit_ranking column
X =loans_df.drop("credit_ranking", axis = 1)
y = loans_df["credit_ranking"]
# Display a sample of y
print (y.head())
# Out:
# 0    0
# 1    0
# 2    0
# 3    1
# 4    0
# Name: credit_ranking, dtype: int64

# %%
# Define features set X by selecting all columns but credit_ranking
#see above cell

# Review the features DataFrame
print(X.head())
# Out:
#    payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 0              7.4                0.70               0.00          1.9
# 1              7.8                0.88               0.00          2.6
# 2              7.8                0.76               0.04          2.3
# 3             11.2                0.28               0.56          1.9
# 4              7.4                0.70               0.00          1.9
#
#    alumni_success  study_major_code  time_to_completion  \
# 0           0.076              11.0                34.0
# 1           0.098              25.0                67.0
# 2           0.092              15.0                54.0
# 3           0.075              17.0                60.0
# 4           0.076              11.0                34.0
#
#    finance_workshop_score  cohort_ranking  total_loan_score  \
# 0                  0.9978            3.51              0.56
# 1                  0.9968            3.20              0.68
# ...

# %% [markdown]
# ### Step 3: Split the features and target sets into training and testing datasets.

# %%
# Split the preprocessed data into a training and testing dataset
# Assign the function a random_state equal to 1
X_train,X_test,y_train, y_test = train_test_split(X,y, random_state=1)

# %% [markdown]
# ### Step 4: Use scikit-learn's `StandardScaler` to scale the features data.

# %%
#question - I scaled as part of preprocessing should I do this again?  or swap when to scale?

# %%
#scale and fit training and test data
scaler = StandardScaler().fit(X_train)

# Scaling the training data
X_train_scaled = scaler.transform(X_train)

# Scaling the test data using the same scaler
X_test_scaled = scaler.transform(X_test)

# %%
transformed_features = X_train_scaled
print(transformed_features)
# Out:
# [[-0.56794375 -1.18088385 -0.19241296 ...  0.73249574 -0.22553894
#   -0.31915735]
#  [-0.00940983  0.80065564 -0.04123135 ... -0.03016065 -0.75844691
#   -1.15783431]
#  [ 2.33643265 -0.84597577  1.67216021 ... -1.36480934  0.42579302
#    0.05358797]
#  ...
#  [-0.9589175   1.07974571 -0.89792713 ...  0.22405814 -0.9952949
#    0.33314696]
#  [-0.62379715  0.54947458 -1.35147195 ...  0.35116754 -0.46238693
#   -1.34420697]
#  [ 0.43741731 -0.73433974  1.16822152 ... -0.66570765  0.18894504
#    1.91731456]]

# %% [markdown]
# ---
#
# ## Compile and Evaluate a Model Using a Neural Network

# %% [markdown]
# ### Step 1: Create a deep neural network by assigning the number of input features, the number of layers, and the number of neurons on each layer using Tensorflow’s Keras.
#
# > **Hint** You can start with a two-layer deep neural network model that uses the `relu` activation function for both layers.

# %%
# Define the the number of inputs (features) to the model

number_input_features = len(transformed_features[0])
# Review the number of features
print(X)
# Out:
#       payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 0                 7.4               0.700               0.00          1.9
# 1                 7.8               0.880               0.00          2.6
# 2                 7.8               0.760               0.04          2.3
# 3                11.2               0.280               0.56          1.9
# 4                 7.4               0.700               0.00          1.9
# ...               ...                 ...                ...          ...
# 1594              6.2               0.600               0.08          2.0
# 1595              5.9               0.550               0.10          2.2
# 1596              6.3               0.510               0.13          2.3
# 1597              5.9               0.645               0.12          2.0
# 1598              6.0               0.310               0.47          3.6
#
#       alumni_success  study_major_code  time_to_completion  \
# ...

# %%
#Create the Sequential model
nn_model = tf.keras.models.Sequential()
#define deep neural net

hidden_nodes_layer1 = 2
hidden_nodes_layer2 = 3
# Define the number of hidden nodes for the first hidden layer

nn_model.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, activation="relu", input_dim=number_input_features))

# Define the number of hidden nodes for the second hidden layer
nn_model.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Define the number of neurons in the output layer
nn_model.add(tf.keras.layers.Dense(units = 1, activation ="sigmoid"))

#check the structure of hte model
nn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 2)                 24
#
#  dense_1 (Dense)             (None, 3)                 9
#
#  dense_2 (Dense)             (None, 1)                 4
#
# ...
# Total params: 37 (148.00 Byte)
# Trainable params: 37 (148.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Step 2: Compile and fit the model using the `binary_crossentropy` loss function, the `adam` optimizer, and the `accuracy` evaluation metric.

# %%
# Compile the Sequential model
nn_model.compile(loss = "binary_crossentropy", optimizer = "adam", metrics= ["accuracy"])

# %%
# Fit the model using 50 epochs and the training data
fit_model = nn_model.fit(X_train_scaled,y_train,epochs=50)
# Out:
# Epoch 1/50
# 38/38 [==============================] - 2s 4ms/step - loss: 0.7452 - accuracy: 0.5638
# Epoch 2/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.7230 - accuracy: 0.5855
# Epoch 3/50
# 38/38 [==============================] - 0s 5ms/step - loss: 0.7064 - accuracy: 0.5938
# Epoch 4/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6921 - accuracy: 0.6072
# Epoch 5/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6798 - accuracy: 0.6155
# Epoch 6/50
# 38/38 [==============================] - 0s 5ms/step - loss: 0.6698 - accuracy: 0.6239
# Epoch 7/50
# 38/38 [==============================] - 0s 4ms/step - loss: 0.6608 - accuracy: 0.6405
# Epoch 8/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.6533 - accuracy: 0.6505
# Epoch 9/50
# 38/38 [==============================] - 0s 5ms/step - loss: 0.6459 - accuracy: 0.6614
# Epoch 10/50
# ...

# %% [markdown]
# ### Step 3: Evaluate the model using the test data to determine the model’s loss and accuracy.

# %%
# Evaluate the model loss and accuracy metrics using the evaluate method and the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled, y_test, verbose=2)


# Display the model loss and accuracy results
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 13/13 - 0s - loss: 0.5212 - accuracy: 0.7400 - 137ms/epoch - 11ms/step
# Loss: 0.5211632251739502, Accuracy: 0.7400000095367432

# %% [markdown]
# ### Step 4: Save and export your model to a keras file, and name the file `student_loans.keras`.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Set the model's file path
file_path = Path("/content/drive/MyDrive/dev/student_loans.keras")

# Export your model to a keras file
nn_model.save(file_path)

# %% [markdown]
# ---
# ## Predict Loan Repayment Success by Using your Neural Network Model

# %% [markdown]
# ### Step 1: Reload your saved model.

# %%
# Set the model's file path

file_path = Path("/content/drive/MyDrive/dev/student_loans.keras")
# Load the model to a new object
nn_imported = tf.keras.models.load_model(file_path)

# %% [markdown]
# ### Step 2: Make predictions on the testing data and save the predictions to a DataFrame.

# %%
# Make predictions with the test data
predictions = nn_imported.predict(X_test_scaled, verbose = 2)

# Display a sample of the predictions
predictions
# Out:
# 13/13 - 0s - 31ms/epoch - 2ms/step
# array([[0.67603815],
#        [0.3182761 ],
#        [0.77489173],
#        [0.6284558 ],
#        [0.9410668 ],
#        [0.61994034],
#        [0.8148601 ],
#        [0.16318502],
#        [0.65890205],
#        [0.3753125 ],
#        [0.8529509 ],
#        [0.3615677 ],
#        [0.5261644 ],
#        [0.70041597],
#        [0.42435625],
#        [0.46111086],
#        [0.8375781 ],
#        [0.54101306],
#        [0.6306281 ],
#        [0.36287972],
#        [0.55224895],
#        [0.6805924 ],
#        [0.45872703],
#        [0.85483813],
#        [0.47896147],
#        [0.9053755 ],
#        [0.6388573 ],
#        [0.6521827 ],
#        [0.35527197],
#        [0.695723  ],
#        [0.22749743],
#        [0.79037744],
#        [0.16482145],
#        [0.7979882 ],
#        [0.16425638],
#        [0.49748287],
#        [0.45087308],
#        [0.38841745],
#        [0.8517869 ],
#        [0.2688952 ],
#        [0.79247767],
# ...

# %%
# Save the predictions to a DataFrame and round the predictions to binary results
predictions_df = pd.DataFrame(columns=["predictions"], data = predictions)
predictions_df["predictions"] = round(predictions_df["predictions"],0)
predictions_df.head()
# Out:
#    predictions
# 0          1.0
# 1          0.0
# 2          1.0
# 3          1.0
# 4          1.0

# %% [markdown]
# ### Step 4: Display a classification report with the y test data and predictions

# %%
# Print the classification report with the y test data and predictions
print(classification_report(y_test, predictions_df["predictions"].values))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.69      0.71       188
#            1       0.74      0.78      0.76       212
#
#     accuracy                           0.74       400
#    macro avg       0.74      0.74      0.74       400
# weighted avg       0.74      0.74      0.74       400

# %% [markdown]
# ---
# ## Discuss creating a recommendation system for student loans

# %% [markdown]
# Briefly answer the following questions in the space provided:
#
# 1. Describe the data that you would need to collect to build a recommendation system to recommend student loan options for students. Explain why this data would be relevant and appropriate.
#
# We'd need to collect data on past history for payments of loans, if they have credit scores and what those values are, along with total amounts.  These would give the information on past payment history, the score used by the industry and also amount of current liabilities.  Adding any sources of income could help establish if they could be eligible for different terms for loans and also help stratify applicants to different loan packages based on recomendation scores.  In addition we could add academic information, driving and/or criminal histories, and insurance related information with the goal of creating a behavior profile for applicants and something against which to compare them to.
#
# 2. Based on the data you chose to use in this recommendation system, would your model be using collaborative filtering, content-based filtering, or context-based filtering? Justify why the data you selected would be suitable for your choice of filtering method.
#
# My system would be using both content-based filtering as we're comparing data we have against a profile of the applicant we've created, and collaborative because we compare the applicant to another that looks similar in our model.  The data we collect creates a profile of the applicants both individually and as a group.  This could help fill in gaps if a applicant doesnt have a history to use for consideration or limitd information given that they probably are younger, and have limited history in financial activities.
#
# 3. Describe two real-world challenges that you would take into consideration while building a recommendation system for student loans. Explain why these challenges would be of concern for a student loan recommendation system.
#
# Two challenges I'd take into consideration are the Cold-start problem and Data sparseness.  As described above, our applicants are new to the "adult" world, and probably have limited histories with loans and credit. This lack of data on which to build creditworthiness requires searching for other perceived data elements that may provide proxy information regarding behaviors involving assets, or items of value.   This could include driving records, insurance claims etc.  Basically we'd be looking to build a profile that uses data that could paint a picture of propensity for risky behaviors.  Schooling and academic performance could be profiled to see what if any relationship there is, along with completion of education and other awareness and skill building activities.

# %% [markdown]
# **1. Describe the data that you would need to collect to build a recommendation system to recommend student loan options for students. Explain why this data would be relevant and appropriate.**
#
#
# **2. Based on the data you chose to use in this recommendation system, would your model be using collaborative filtering, content-based filtering, or context-based filtering? Justify why the data you selected would be suitable for your choice of filtering method.**
#
#
# **3. Describe two real-world challenges that you would take into consideration while building a recommendation system for student loans. Explain why these challenges would be of concern for a student loan recommendation system.**
